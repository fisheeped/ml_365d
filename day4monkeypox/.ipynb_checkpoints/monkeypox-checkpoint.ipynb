# %% [markdown]
# <h1>👇本周任务挑战</h1></div> <div class="markdown-body"><div class="markdown-body"><h1 id="猴痘病识别"><strong>猴痘病识别</strong></h1>
# <p><strong>5天学习计划-第4周</strong></p>
# <p>选题：猴痘病识别<br>难度：夯实基础🌟🌟<br>语言：Python3、TensorFlow2<br>时间：8月15-8月19日</p>
# <p>🍺要求：</p>
# <ol>
# <li>训练过程中保存效果最好的模型参数（完成）。</li>
# <li>加载最佳模型参数识别本地的一张图片（完成）。</li>
# <li>测试集accuracy到达88%（完成）。</li>
# </ol>
# <p>参考文章： <a target="_blank" href="https://blog.csdn.net/qq_38251616/article/details/126284706">https://blog.csdn.net/qq_38251616/article/details/126284706</a> （限时免费）</p>
# <p><img src="https://cdn.kesci.com/upload/image/rghp5n5nzt.jpeg?imageView2/0/w/960/h/960" alt="Image Name"></p>
# <h2 id="支持数据"><strong>支持数据</strong></h2>
# <p><a target="_blank" href="https://www.heywhale.com/mw/dataset/62f4a661a1b28ef211ce82fa/file">猴痘数据集</a></p>
# <h2 id="所有数据集可直接在线使用">所有数据集可直接在线使用</h2>

# %% [markdown]
# ## 数据解压

# %%
import zipfile
f = zipfile.ZipFile("./monkeypox.zip")
for file in f.namelist():
    f.extract(file,"./")
f.close()

# %% [markdown]
# # 设置GPU
# 如果没有GPU不用设置

# %%
from tensorflow import keras
from tensorflow.keras import layers,models
import os, PIL, pathlib
import matplotlib.pyplot as plt
import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")

if gpus:
    gpu0 = gpus[0]                                        #如果有多个GPU，仅使用第0个GPU
    tf.config.experimental.set_memory_growth(gpu0, True)  #设置GPU显存用量按需使用
    tf.config.set_visible_devices([gpu0],"GPU")
    
gpus
# Out:
# []

# %% [markdown]
# # 导入数据

# %%
data_dir = "./monkeypox"

data_dir = pathlib.Path(data_dir)

# %% [markdown]
# # 查看数据结构

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))

print("图片总数为：",image_count)
# Out:
# 图片总数为： 2142

# %%
Monkeypox = list(data_dir.glob('Monkeypox/*.jpg'))
PIL.Image.open(str(Monkeypox[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
"""
关于image_dataset_from_directory()的详细介绍可以参考文章：https://mtyjkh.blog.csdn.net/article/details/117018789
"""
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 2142 files belonging to 2 classes.
# Using 1714 files for training.

# %%
"""
关于image_dataset_from_directory()的详细介绍可以参考文章：https://mtyjkh.blog.csdn.net/article/details/117018789
"""
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 2142 files belonging to 2 classes.
# Using 428 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Monkeypox', 'Others']

# %%
plt.figure(figsize=(20, 10))

for images, labels in train_ds.take(1):
    for i in range(20):
        ax = plt.subplot(5, 10, i + 1)

        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = 2

"""
关于卷积核的计算不懂的可以参考文章：https://blog.csdn.net/qq_38251616/article/details/114278995

layers.Dropout(0.4) 作用是防止过拟合，提高模型的泛化能力。
在上一篇文章花朵识别中，训练准确率与验证准确率相差巨大就是由于模型过拟合导致的

关于Dropout层的更多介绍可以参考文章：https://mtyjkh.blog.csdn.net/article/details/115826689
"""

model = models.Sequential([
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    
    layers.Conv2D(16, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)), # 卷积层1，卷积核3*3  
    layers.AveragePooling2D((2, 2)),               # 池化层1，2*2采样
    layers.Conv2D(32, (3, 3), activation='relu'),  # 卷积层2，卷积核3*3
    layers.AveragePooling2D((2, 2)),               # 池化层2，2*2采样
    layers.Dropout(0.3),  
    layers.Conv2D(64, (3, 3), activation='relu'),  # 卷积层3，卷积核3*3
    layers.Dropout(0.3),  
    
    layers.Flatten(),                       # Flatten层，连接卷积层与全连接层
    layers.Dense(128, activation='relu'),   # 全连接层，特征进一步提取
    layers.Dense(num_classes)               # 输出层，输出预期结果
])

model.summary()  # 打印网络结构
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 222, 222, 16)      448
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 32)      4640
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 54, 54, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 64)        18496
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 52, 52, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 173056)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               22151296
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 22,175,138
# Trainable params: 22,175,138
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 设置优化器
opt = tf.keras.optimizers.Adam(learning_rate=1e-4)

model.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

epochs = 50

checkpointer = ModelCheckpoint('best_model.h5',
                                monitor='val_accuracy',
                                verbose=1,
                                save_best_only=True,
                                save_weights_only=True)

history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=epochs,
                    callbacks=[checkpointer])
# Out:
# Epoch 1/50
# 54/54 [==============================] - 17s 282ms/step - loss: 0.7568 - accuracy: 0.5472 - val_loss: 0.6678 - val_accuracy: 0.5888
#
# Epoch 00001: val_accuracy improved from -inf to 0.58879, saving model to best_model.h5
# Epoch 2/50
# 54/54 [==============================] - 15s 273ms/step - loss: 0.6642 - accuracy: 0.6100 - val_loss: 0.6327 - val_accuracy: 0.6542
#
# Epoch 00002: val_accuracy improved from 0.58879 to 0.65421, saving model to best_model.h5
# Epoch 3/50
# 54/54 [==============================] - 15s 271ms/step - loss: 0.6056 - accuracy: 0.6790 - val_loss: 0.6968 - val_accuracy: 0.6238
#
# Epoch 00003: val_accuracy did not improve from 0.65421
# Epoch 4/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.5847 - accuracy: 0.6888 - val_loss: 0.5944 - val_accuracy: 0.7009
#
# Epoch 00004: val_accuracy improved from 0.65421 to 0.70093, saving model to best_model.h5
# Epoch 5/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.5503 - accuracy: 0.7070 - val_loss: 0.5372 - val_accuracy: 0.7336
#
# Epoch 00005: val_accuracy improved from 0.70093 to 0.73364, saving model to best_model.h5
# Epoch 6/50
# 54/54 [==============================] - 15s 272ms/step - loss: 0.5284 - accuracy: 0.7591 - val_loss: 0.5545 - val_accuracy: 0.7243
#
# Epoch 00006: val_accuracy did not improve from 0.73364
# Epoch 7/50
# 54/54 [==============================] - 15s 272ms/step - loss: 0.4861 - accuracy: 0.7696 - val_loss: 0.4655 - val_accuracy: 0.7593
#
# Epoch 00007: val_accuracy improved from 0.73364 to 0.75935, saving model to best_model.h5
# Epoch 8/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.4484 - accuracy: 0.8124 - val_loss: 0.4486 - val_accuracy: 0.7780
#
# Epoch 00008: val_accuracy improved from 0.75935 to 0.77804, saving model to best_model.h5
# Epoch 9/50
# 54/54 [==============================] - 14s 268ms/step - loss: 0.4358 - accuracy: 0.8004 - val_loss: 0.4394 - val_accuracy: 0.7827
#
# Epoch 00009: val_accuracy improved from 0.77804 to 0.78271, saving model to best_model.h5
# Epoch 10/50
# 54/54 [==============================] - 15s 271ms/step - loss: 0.3776 - accuracy: 0.8428 - val_loss: 0.4072 - val_accuracy: 0.8364
#
# Epoch 00010: val_accuracy improved from 0.78271 to 0.83645, saving model to best_model.h5
# Epoch 11/50
# 54/54 [==============================] - 15s 269ms/step - loss: 0.3570 - accuracy: 0.8524 - val_loss: 0.4360 - val_accuracy: 0.7897
#
# Epoch 00011: val_accuracy did not improve from 0.83645
# Epoch 12/50
# 54/54 [==============================] - 15s 273ms/step - loss: 0.3379 - accuracy: 0.8654 - val_loss: 0.4043 - val_accuracy: 0.8084
#
# Epoch 00012: val_accuracy did not improve from 0.83645
# Epoch 13/50
# 54/54 [==============================] - 15s 269ms/step - loss: 0.3141 - accuracy: 0.8701 - val_loss: 0.3937 - val_accuracy: 0.8294
#
# Epoch 00013: val_accuracy did not improve from 0.83645
# Epoch 14/50
# 54/54 [==============================] - 14s 269ms/step - loss: 0.3006 - accuracy: 0.8773 - val_loss: 0.4089 - val_accuracy: 0.8248
#
# Epoch 00014: val_accuracy did not improve from 0.83645
# Epoch 15/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.2989 - accuracy: 0.8763 - val_loss: 0.4268 - val_accuracy: 0.7944
#
# Epoch 00015: val_accuracy did not improve from 0.83645
# Epoch 16/50
# 54/54 [==============================] - 14s 268ms/step - loss: 0.3326 - accuracy: 0.8644 - val_loss: 0.3741 - val_accuracy: 0.8621
#
# Epoch 00016: val_accuracy improved from 0.83645 to 0.86215, saving model to best_model.h5
# Epoch 17/50
# 54/54 [==============================] - 15s 269ms/step - loss: 0.2449 - accuracy: 0.9085 - val_loss: 0.3581 - val_accuracy: 0.8341
#
# Epoch 00017: val_accuracy did not improve from 0.86215
# Epoch 18/50
# 54/54 [==============================] - 15s 272ms/step - loss: 0.2345 - accuracy: 0.9099 - val_loss: 0.3616 - val_accuracy: 0.8458
#
# Epoch 00018: val_accuracy did not improve from 0.86215
# Epoch 19/50
# 54/54 [==============================] - 15s 269ms/step - loss: 0.2363 - accuracy: 0.9040 - val_loss: 0.3920 - val_accuracy: 0.8598
#
# Epoch 00019: val_accuracy did not improve from 0.86215
# Epoch 20/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.2571 - accuracy: 0.8962 - val_loss: 0.3969 - val_accuracy: 0.8435
#
# Epoch 00020: val_accuracy did not improve from 0.86215
# Epoch 21/50
# 54/54 [==============================] - 15s 269ms/step - loss: 0.1895 - accuracy: 0.9342 - val_loss: 0.3732 - val_accuracy: 0.8481
#
# Epoch 00021: val_accuracy did not improve from 0.86215
# Epoch 22/50
# 54/54 [==============================] - 14s 269ms/step - loss: 0.1788 - accuracy: 0.9405 - val_loss: 0.3747 - val_accuracy: 0.8598
#
# Epoch 00022: val_accuracy did not improve from 0.86215
# Epoch 23/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.1771 - accuracy: 0.9380 - val_loss: 0.3846 - val_accuracy: 0.8668
#
# Epoch 00023: val_accuracy improved from 0.86215 to 0.86682, saving model to best_model.h5
# Epoch 24/50
# 54/54 [==============================] - 15s 272ms/step - loss: 0.1545 - accuracy: 0.9433 - val_loss: 0.4067 - val_accuracy: 0.8481
#
# Epoch 00024: val_accuracy did not improve from 0.86682
# Epoch 25/50
# 54/54 [==============================] - 15s 272ms/step - loss: 0.1706 - accuracy: 0.9302 - val_loss: 0.3946 - val_accuracy: 0.8598
#
# Epoch 00025: val_accuracy did not improve from 0.86682
# Epoch 26/50
# 54/54 [==============================] - 15s 269ms/step - loss: 0.1481 - accuracy: 0.9478 - val_loss: 0.3896 - val_accuracy: 0.8621
#
# Epoch 00026: val_accuracy did not improve from 0.86682
# Epoch 27/50
# 54/54 [==============================] - 14s 267ms/step - loss: 0.1332 - accuracy: 0.9562 - val_loss: 0.4381 - val_accuracy: 0.8481
#
# Epoch 00027: val_accuracy did not improve from 0.86682
# Epoch 28/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.1244 - accuracy: 0.9590 - val_loss: 0.4120 - val_accuracy: 0.8715
#
# Epoch 00028: val_accuracy improved from 0.86682 to 0.87150, saving model to best_model.h5
# Epoch 29/50
# 54/54 [==============================] - 14s 269ms/step - loss: 0.1500 - accuracy: 0.9390 - val_loss: 0.4211 - val_accuracy: 0.8481
#
# Epoch 00029: val_accuracy did not improve from 0.87150
# Epoch 30/50
# 54/54 [==============================] - 14s 267ms/step - loss: 0.1070 - accuracy: 0.9655 - val_loss: 0.3920 - val_accuracy: 0.8668
#
# Epoch 00030: val_accuracy did not improve from 0.87150
# Epoch 31/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.1052 - accuracy: 0.9693 - val_loss: 0.4107 - val_accuracy: 0.8692
#
# Epoch 00031: val_accuracy did not improve from 0.87150
# Epoch 32/50
# 54/54 [==============================] - 15s 271ms/step - loss: 0.1120 - accuracy: 0.9562 - val_loss: 0.3991 - val_accuracy: 0.8785
#
# Epoch 00032: val_accuracy improved from 0.87150 to 0.87850, saving model to best_model.h5
# Epoch 33/50
# 54/54 [==============================] - 15s 269ms/step - loss: 0.0969 - accuracy: 0.9701 - val_loss: 0.4062 - val_accuracy: 0.8785
#
# Epoch 00033: val_accuracy did not improve from 0.87850
# Epoch 34/50
# 54/54 [==============================] - 15s 272ms/step - loss: 0.0900 - accuracy: 0.9730 - val_loss: 0.4390 - val_accuracy: 0.8692
#
# Epoch 00034: val_accuracy did not improve from 0.87850
# Epoch 35/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.0794 - accuracy: 0.9686 - val_loss: 0.4228 - val_accuracy: 0.8855
#
# Epoch 00035: val_accuracy improved from 0.87850 to 0.88551, saving model to best_model.h5
# Epoch 36/50
# 54/54 [==============================] - 15s 271ms/step - loss: 0.0688 - accuracy: 0.9850 - val_loss: 0.4384 - val_accuracy: 0.8692
#
# Epoch 00036: val_accuracy did not improve from 0.88551
# Epoch 37/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.0642 - accuracy: 0.9829 - val_loss: 0.4361 - val_accuracy: 0.8925
#
# Epoch 00037: val_accuracy improved from 0.88551 to 0.89252, saving model to best_model.h5
# Epoch 38/50
# 54/54 [==============================] - 15s 272ms/step - loss: 0.0529 - accuracy: 0.9880 - val_loss: 0.5128 - val_accuracy: 0.8621
#
# Epoch 00038: val_accuracy did not improve from 0.89252
# Epoch 39/50
# 54/54 [==============================] - 15s 271ms/step - loss: 0.0702 - accuracy: 0.9768 - val_loss: 0.4295 - val_accuracy: 0.8949
# Epoch 00039: val_accuracy improved from 0.89252 to 0.89486, saving model to best_model.h5
# Epoch 40/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.0629 - accuracy: 0.9847 - val_loss: 0.5047 - val_accuracy: 0.8645
#
# Epoch 00040: val_accuracy did not improve from 0.89486
# Epoch 41/50
# 54/54 [==============================] - 15s 271ms/step - loss: 0.0510 - accuracy: 0.9882 - val_loss: 0.4704 - val_accuracy: 0.8715
#
# Epoch 00041: val_accuracy did not improve from 0.89486
# Epoch 42/50
# 54/54 [==============================] - 15s 269ms/step - loss: 0.0435 - accuracy: 0.9940 - val_loss: 0.4735 - val_accuracy: 0.8738
#
# Epoch 00042: val_accuracy did not improve from 0.89486
# Epoch 43/50
# 54/54 [==============================] - 15s 269ms/step - loss: 0.0500 - accuracy: 0.9851 - val_loss: 0.4640 - val_accuracy: 0.8762
#
# Epoch 00043: val_accuracy did not improve from 0.89486
# Epoch 44/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.0462 - accuracy: 0.9872 - val_loss: 0.4520 - val_accuracy: 0.8575
#
# Epoch 00044: val_accuracy did not improve from 0.89486
# Epoch 45/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.0360 - accuracy: 0.9934 - val_loss: 0.4466 - val_accuracy: 0.8925
#
# Epoch 00045: val_accuracy did not improve from 0.89486
# Epoch 46/50
# 54/54 [==============================] - 14s 268ms/step - loss: 0.0513 - accuracy: 0.9859 - val_loss: 0.4997 - val_accuracy: 0.8855
#
# Epoch 00046: val_accuracy did not improve from 0.89486
# Epoch 47/50
# 54/54 [==============================] - 14s 269ms/step - loss: 0.0316 - accuracy: 0.9940 - val_loss: 0.5015 - val_accuracy: 0.8879
#
# Epoch 00047: val_accuracy did not improve from 0.89486
# Epoch 48/50
# 54/54 [==============================] - 15s 269ms/step - loss: 0.0339 - accuracy: 0.9942 - val_loss: 0.5147 - val_accuracy: 0.8808
#
# Epoch 00048: val_accuracy did not improve from 0.89486
# Epoch 49/50
# 54/54 [==============================] - 15s 270ms/step - loss: 0.0242 - accuracy: 0.9953 - val_loss: 0.5862 - val_accuracy: 0.8668
#
# Epoch 00049: val_accuracy did not improve from 0.89486
# Epoch 50/50
# 54/54 [==============================] - 15s 271ms/step - loss: 0.0265 - accuracy: 0.9966 - val_loss: 0.5023 - val_accuracy: 0.8808
#
# Epoch 00050: val_accuracy did not improve from 0.89486

# %%
# 加载效果最好的模型权重
model.load_weights('best_model.h5')

# %%
from PIL import Image
import numpy as np

# img = Image.open("./45-data/Monkeypox/M06_01_04.jpg")  #这里选择你需要预测的图片
img = Image.open("./monkeypox/Others/NM15_02_11.jpg")  #这里选择你需要预测的图片
image = tf.image.resize(np.asarray(img), [img_height, img_width])

img_array = tf.expand_dims(image, 0) 

predictions = model.predict(img_array) # 这里选用你已经训练好的模型
print("预测结果为：",class_names[np.argmax(predictions)])
# Out:
# 预测结果为： Others
